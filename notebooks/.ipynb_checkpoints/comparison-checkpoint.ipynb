# %%
#install.packages("corrplot")
#install.packages("viridisLite") 
#install.packages("viridis")
#install.packages("Hmisc")
#install.packages("corrgram")
library("corrgram")
library("corrplot")
library("Hmisc")
library("dplyr")
# Out:
# corrplot 0.84 loaded
# Loading required package: lattice
# Loading required package: survival
# Loading required package: Formula
# Loading required package: ggplot2
#
# Attaching package: ‘Hmisc’
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:Hmisc’:
#
#     src, summarize
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
scx = read.csv("../csv/sc_xtandem_proteinCounts.csv",head=T)
scx = scx[-1]
names(scx) = c("protein",paste0("scx_",names(scx)[-1]))
head(scx)
# Out:
#   protein               scx_JD_06232014_sample4_Cn_proteins
# 1 sp|D6VTK4|STE2_YEAST  1
# 2 sp|O13297|CET1_YEAST  1
# 3 sp|O13516|RS9A_YEAST  1
# 4 sp|O13547|CCW14_YEAST 1
# 5 sp|O13563|RPN13_YEAST 1
# 6 sp|O13585|YP089_YEAST 1
#   scx_JD_06232014_sample4_Cprotein_score scx_JD_06232014_sample4_Cn_peptides
# 1 1.0000000                              5
# 2 1.0000000                              4
# 3 1.0000000                              1
# 4 1.0000000                              2
# 5 1.0000000                              2
# 6 0.9999803                              1
#   scx_JD_06232014_sample4_Cabundance scx_JD_06232014_sample3_C_n_proteins
# 1 5                                  1
# 2 4                                  1
# 3 1                                  1
# 4 4                                  1
# 5 2                                  1
# 6 1                                  1
#   scx_JD_06232014_sample3_C_protein_score scx_JD_06232014_sample3_C_n_peptides
# 1 1.0000000                               5
# 2 1.0000000                               4
# 3 1.0000000                               1
# 4 1.0000000                               2
# 5 1.0000000                               3
# 6 0.9999803                               1
#   scx_JD_06232014_sample3_C_abundance scx_JD_06232014_sample2_A_n_proteins ⋯
# 1 5                                   1                                    ⋯
# 2 4                                   1                                    ⋯
# 3 1                                   1                                    ⋯
# 4 4                                   1                                    ⋯
# 5 3                                   1                                    ⋯
# 6 1                                   1                                    ⋯
#   scx_JD_06232014_sample3_A_n_peptides scx_JD_06232014_sample3_A_abundance
# 1 5                                    5
# 2 4                                    4
# 3 1                                    1
# 4 2                                    4
# 5 3                                    4
# 6 1                                    1
#   scx_JD_06232014_sample4.A_n_proteins scx_JD_06232014_sample4.A_protein_score
# 1  1                                    1
# 2  1                                    1
# 3  1                                    1
# 4  1                                    1
# 5  1                                    1
# 6 NA                                   NA
#   scx_JD_06232014_sample4.A_n_peptides scx_JD_06232014_sample4.A_abundance
# 1  5                                    5
# 2  5                                    5
# 3  1                                    1
# 4  2                                    4
# 5  2                                    2
# 6 NA                                   NA
#   scx_JD_06232014_sample2_B_n_proteins scx_JD_06232014_sample2_B_protein_score
# 1 1                                    1.0000000
# 2 1                                    1.0000000
# 3 1                                    1.0000000
# 4 1                                    1.0000000
# 5 1                                    1.0000000
# 6 1                                    0.9999803
#   scx_JD_06232014_sample2_B_n_peptides scx_JD_06232014_sample2_B_abundance
# 1 5                                    5
# 2 7                                    8
# 3 1                                    1
# 4 2                                    3
# 5 4                                    4
# 6 1                                    1

# %%
grep("^# Files*","../ffc_xtandem_proteinIntensities.csv",value=T)

getColumnNames = function(filepath) {
  con = file(filepath, "r")
 a = 0 
  while ( TRUE ) {
    a = a+1
    line = readLines(con, n = 1)
    if ( length(line) == 0 ) {
      break
    } else if (length(grep("# Files/samples associated with abundance values below: ",line)) > 0) {
        tmpline = gsub("# Files/samples associated with abundance values below: ","",line)
        linestrip = unlist(strsplit(tmpline,","))
        #print(linestrip)
        for (i in 1:length(linestrip)) { 
            #print(linestrip[i])
            tmpline = gsub("^ ","",linestrip[i])
            #print(tmpline)
            linestrip[i] = gsub("^.*\\/.*\\/(.*)\\/.*","\\1",tmpline)
  }
        break
    }
        
  }

    close(con)
    return (linestrip)
}
# Out:
# character(0)

# %%
filepaths = c("../ffc_xtandem_proteinIntensities.csv",
              "../ffm_xtandem_proteinIntensities.csv",
              "../ffidi_xtandem_proteinIntensities.csv",
              "../ffc_msgfplus_proteinIntensities.csv",
              "../ffm_msgfplus_proteinIntensities.csv",
              "../ffidi_msgfplus_proteinIntensities.csv"
             )
for (i in 1:length(filepaths)) {
    filepath = filepaths[i]
    fftype = gsub("^.*\\/(.*)_(.*)_.*","\\1_\\2_",filepath)
    #print(fftype)
    ff = read.table(filepath,head=T,stringsAsFactors=F)
    #print(head(ff))
    names(ff) = c(names(ff[1]),paste0(fftype, c(names(ff[2:4]),getColumnNames(filepath))))
    #print(names(ff))
    
    if (i == 1) ffj = ff
    else ffj = full_join(ffj,ff,by="protein")
    
}
head(ffj)
# Out:
#   protein               ffc_xtandem_n_proteins ffc_xtandem_protein_score
# 1 sp|D6VTK4|STE2_YEAST  1                      1.0000000
# 2 sp|O13297|CET1_YEAST  1                      1.0000000
# 3 sp|O13329|FOB1_YEAST  1                      0.9999938
# 4 sp|O13515|YA034_YEAST 1                      0.1604198
# 5 sp|O13516|RS9A_YEAST  1                      1.0000000
# 6 sp|O13521|YP035_YEAST 1                      0.1629821
#   ffc_xtandem_n_peptides ffc_xtandem_JD_06232014_sample4_C
# 1 6                      325810900
# 2 7                      138552000
# 3 3                      122663980
# 4 1                              0
# 5 1                       46545900
# 6 1                      168850000
#   ffc_xtandem_JD_06232014_sample3_C ffc_xtandem_JD_06232014_sample2_A
# 1 368869300                         428647900
# 2  83701500                         150431800
# 3 102951000                          59816840
# 4  99177696                          80289000
# 5  59508700                          36443000
# 6 174526000                         111573000
#   ffc_xtandem_JD_06232014_sample2_C ffc_xtandem_JD_06232014_sample3_B
# 1 352240200                         397596896
# 2 139657100                         165265100
# 3 136478010                          82725830
# 4         0                                 0
# 5  60347400                          53226900
# 6 151418000                         255892000
#   ffc_xtandem_JD_06232014_sample4_B ⋯ ffidi_msgfplus_JD_06232014_sample2_A
# 1 395880500                         ⋯ 1657118444
# 2 148537900                         ⋯  163484410
# 3  71730620                         ⋯          0
# 4         0                         ⋯         NA
# 5  39296200                         ⋯          0
# 6 126187000                         ⋯         NA
#   ffidi_msgfplus_JD_06232014_sample2_C ffidi_msgfplus_JD_06232014_sample3_B
# 1 1478127736                           1441496432
# 2  156678800                            248175500
# 3   12858000                             11333400
# 4         NA                                   NA
# 5          0                             84882800
# 6         NA                                   NA
#   ffidi_msgfplus_JD_06232014_sample4_B ffidi_msgfplus_JD_06232014_sample1_B
# 1 1658191928                           1952373800
# 2  182785260                            355262700
# 3          0                             10575700
# 4         NA                                   NA
# 5          0                             81423000
# 6         NA                                   NA
#   ffidi_msgfplus_JD_06232014_sample1_C ffidi_msgfplus_JD_06232014_sample1-A
# 1 1450922560                           1355230088
# 2  248771700                            201424640
# 3   11117700                                    0
# 4         NA                                   NA
# 5          0                             88520800
# 6         NA                                   NA
#   ffidi_msgfplus_JD_06232014_sample3_A ffidi_msgfplus_JD_06232014_sample4-A
# 1 1268214788                           1790191784
# 2  155884430                            154186700
# 3   26396400                             91011504
# 4         NA                                   NA
# 5          0                                    0
# 6         NA                                   NA
#   ffidi_msgfplus_JD_06232014_sample2_B
# 1 1865465216
# 2  250505800
# 3   26775800
# 4         NA
# 5   92403904
# 6         NA

# %%
#names(ffj)
sample = "JD_06232014_sample2_A"
tdf = log(ffj[,grep(sample,names(ffj),value=T)])
names(tdf) = gsub(sample,"",names(tdf))
pairs(tdf,main=sample)
# Out:
# plot without title

# %%
tdf[tdf == -Inf] <- 0
tdf_cor = rcorr(as.matrix(tdf))
tdf_cor
#summary(tdf)
corrgram(tdf,
         lower.panel=panel.ellipse,
         upper.panel=panel.pts, diag.panel=panel.minmax
        )
# Out:
#                 ffc_xtandem_ ffm_xtandem_ ffidi_xtandem_ ffc_msgfplus_
# ffc_xtandem_            1.00         0.19           0.46          0.67
# ffm_xtandem_            0.19         1.00           0.20          0.15
# ffidi_xtandem_          0.46         0.20           1.00          0.51
# ffc_msgfplus_           0.67         0.15           0.51          1.00
# ffm_msgfplus_           0.21         0.94           0.17          0.16
# ffidi_msgfplus_         0.42         0.19           0.74          0.51
#                 ffm_msgfplus_ ffidi_msgfplus_
# ffc_xtandem_             0.21            0.42
# ffm_xtandem_             0.94            0.19
# ffidi_xtandem_           0.17            0.74
# ffc_msgfplus_            0.16            0.51
# ffm_msgfplus_            1.00            0.16
# ffidi_msgfplus_          0.16            1.00
#
# n
#                 ffc_xtandem_ ffm_xtandem_ ffidi_xtandem_ ffc_msgfplus_
# ffc_xtandem_            3861          850           3727          3280
# ffm_xtandem_             850          872            859           818
# ffidi_xtandem_          3727          859           4346          3389
# ffc_msgfplus_           3280          818           3389          3616
# ffm_msgfplus_            743          698            751           750
# ffidi_msgfplus_         3525          843           3860          3545
#                 ffm_msgfplus_ ffidi_msgfplus_
# ffc_xtandem_              743            3525
# ffm_xtandem_              698             843
# ffidi_xtandem_            751            3860
# ffc_msgfplus_             750            3545
# ffm_msgfplus_             757             756
# ffidi_msgfplus_           756            4409
#
# P
#                 ffc_xtandem_ ffm_xtandem_ ffidi_xtandem_ ffc_msgfplus_
# ffc_xtandem_                  0            0              0
# ffm_xtandem_     0                         0              0
# ffidi_xtandem_   0            0                           0
# ffc_msgfplus_    0            0            0
# ffm_msgfplus_    0            0            0              0
# ffidi_msgfplus_  0            0            0              0
#                 ffm_msgfplus_ ffidi_msgfplus_
# ffc_xtandem_     0             0
# ffm_xtandem_     0             0
# ffidi_xtandem_   0             0
# ffc_msgfplus_    0             0
# ffm_msgfplus_                  0
# ffidi_msgfplus_  0
# plot without title
